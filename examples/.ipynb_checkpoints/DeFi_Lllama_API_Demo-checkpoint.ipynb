# %% [markdown]
# # DeFi Llama

# %% [markdown]
# This tutorial aims to be a quick guide to get you started using the DeFi Llama API integrated into messari's python library.

# %%
from messari.defillama import DeFiLlama
dl = DeFiLlama()

# %% [markdown]
# ## get_protocol_tvl_timeseries

# %% [markdown]
# Returns times TVL of a protocol with token amounts as a pandas DataFrame indexed by df[protocol][chain][asset].
#
# To look at total tvl across all chains, index with chain='all'.
#
# To look at total tvl across all tokens of a chain, asset='totalLiquidityUSD'.
#
# Tokens can be indexed by native amount, asset='tokenName', or by USD amount, asset='tokenName_usd'.

# %%
protocols = ['aave']
protocol_tvls = dl.get_protocol_tvl_timeseries(protocols, start_date="2021-10-01", end_date="2021-10-10")
protocol_tvls['aave']['all']
# Out:
#             totalLiquidityUSD           ENJ           CRV          USDT  \
# 2021-10-01       1.370234e+10  1.046651e+07  6.311565e+06  2.455208e+08
# 2021-10-02       1.419310e+10  1.057785e+07  6.935109e+06  2.275302e+08
# 2021-10-03       1.431644e+10  1.063210e+07  7.733310e+06  3.273912e+08
# 2021-10-04       1.481314e+10  1.062416e+07  7.951371e+06  3.380871e+08
# 2021-10-05       1.562776e+10  1.060164e+07  8.145123e+06  3.916334e+08
# 2021-10-06       1.562115e+10  1.067482e+07  8.144579e+06  3.940461e+08
# 2021-10-07       1.569708e+10  1.063882e+07  8.153192e+06  3.644225e+08
# 2021-10-08       1.523661e+10  1.063787e+07  8.375301e+06  2.265117e+08
# 2021-10-09       1.496834e+10  1.058577e+07  7.823779e+06  2.666035e+08
# 2021-10-10       1.491515e+10  1.058498e+07  7.946344e+06  2.619740e+08
#
#                      LEND          AAVE           UNI          WBTC  \
# 2021-10-01  174907.299479  1.910542e+06  3.918288e+06  41781.707197
# 2021-10-02  174907.299479  1.912798e+06  4.063942e+06  42631.168237
# 2021-10-03  174907.299479  1.910459e+06  4.060696e+06  43108.704933
# 2021-10-04  174907.299479  2.024898e+06  4.119227e+06  44953.703369
# 2021-10-05  174296.741465  2.081462e+06  4.122575e+06  45576.912796
# 2021-10-06  174296.741465  2.079962e+06  4.145569e+06  45729.656044
# 2021-10-07  174296.741465  2.125935e+06  4.663488e+06  44682.113527
# 2021-10-08  174296.741465  2.077710e+06  4.481779e+06  37411.148167
# 2021-10-09  174296.741465  2.083616e+06  4.448296e+06  37263.591623
# 2021-10-10  174296.741465  2.105858e+06  4.424556e+06  35344.264960
#
#                     SUSD          LINK  ...    RENFIL_usd  \
# 2021-10-01  2.544456e+07  2.200474e+07  ...  4.142907e+06
# 2021-10-02  2.483117e+07  2.211693e+07  ...  4.275809e+06
# 2021-10-03  2.256727e+07  2.216695e+07  ...  4.120871e+06
# 2021-10-04  2.232785e+07  2.216039e+07  ...  4.092038e+06
# 2021-10-05  1.488648e+07  2.214311e+07  ...  4.184423e+06
# 2021-10-06  1.486158e+07  2.215770e+07  ...  4.184423e+06
# 2021-10-07  1.318252e+07  2.215770e+07  ...  4.173831e+06
# 2021-10-08  1.207873e+07  2.216636e+07  ...  4.083407e+06
# 2021-10-09  1.283640e+07  2.218492e+07  ...  4.572600e+06
# 2021-10-10  1.270234e+07  2.214507e+07  ...  4.359710e+06
#
#             UNKNOWN (0x1985365e9f78359a9B6AD760e32412f4a445E862)_usd  \
# 2021-10-01                                                NaN
# 2021-10-02                                                NaN
# 2021-10-03                                                NaN
# 2021-10-04                                                NaN
# 2021-10-05                                                NaN
# 2021-10-06                                                NaN
# 2021-10-07                                                NaN
# 2021-10-08                                                NaN
# 2021-10-09                                                NaN
# 2021-10-10                                                NaN
#
#                  RAI_usd      AMPL_usd  PAX_usd       DPI_usd      USDP_usd  \
# 2021-10-01  1.369684e+07  1.067524e+06      NaN  5.856352e+07  2.990423e+06
# 2021-10-02  1.513579e+07  1.651881e+05      NaN  4.688960e+07  2.970062e+06
# 2021-10-03  1.513579e+07  2.528140e+05      NaN  4.588331e+07  2.931041e+06
# 2021-10-04  1.536486e+07  3.413756e+05      NaN  4.441723e+07  2.931041e+06
# 2021-10-05  1.481286e+07  1.000055e+06      NaN  4.478705e+07  2.931041e+06
# 2021-10-06  1.481286e+07  9.903454e+05      NaN  4.471258e+07  2.930671e+06
# 2021-10-07  1.453803e+07  1.755345e+06      NaN  4.442106e+07  1.954104e+06
# 2021-10-08  1.429536e+07  1.719844e+06      NaN  4.513997e+07  1.955210e+06
# 2021-10-09  4.113153e+06  1.460316e+06      NaN  4.541627e+07  1.887495e+06
# 2021-10-10  1.536904e+07  1.404938e+06      NaN  4.545979e+07  1.653666e+06
#
#                 FRAX_usd       FEI_usd     WAVAX_usd
# 2021-10-01  1.601764e+06  4.276806e+06           NaN
# 2021-10-02  3.600939e+06  4.036727e+06           NaN
# 2021-10-03  2.859444e+06  5.071526e+06           NaN
# 2021-10-04  1.647494e+06  5.114161e+06  8.102013e+07
# 2021-10-05  1.834846e+06  5.018526e+06  8.322869e+07
# 2021-10-06  1.834846e+06  5.018526e+06  8.284358e+07
# 2021-10-07  3.854846e+06  5.545350e+06  9.287609e+07
# 2021-10-08  3.631679e+06  4.228806e+06  1.895730e+08
# 2021-10-09  4.772514e+06  6.182420e+06  2.243448e+08
# 2021-10-10  4.392514e+06  5.690131e+06  2.346596e+08
#
# [10 rows x 77 columns]

# %% [markdown]
# ## get_global_tvl_timeseries

# %% [markdown]
# Returns timeseries TVL from total of all Defi Llama supported protocols as a pandas DataFrame

# %%
global_tvl = dl.get_global_tvl_timeseries(start_date="2021-10-01", end_date="2021-10-10")
global_tvl
# Out:
#             totalLiquidityUSD
# 2021-10-01       1.931929e+11
# 2021-10-02       1.975269e+11
# 2021-10-03       2.000398e+11
# 2021-10-04       2.010004e+11
# 2021-10-05       2.052809e+11
# 2021-10-06       2.050247e+11
# 2021-10-07       2.074607e+11
# 2021-10-08       2.110497e+11
# 2021-10-09       2.116465e+11
# 2021-10-10       2.129363e+11

# %% [markdown]
# ## get_chain_tvl_timeseries

# %% [markdown]
# Retrive timeseries TVL for a given chain or list of chains as a pandas DataFrame

# %%
chains = ["Avalanche", "Harmony", "Polygon"]
chain_tvls = dl.get_chain_tvl_timeseries(chains, start_date="2021-10-01", end_date="2021-10-10")
chain_tvls
# Out:
#                Avalanche       Harmony       Polygon
# 2021-10-01  3.880313e+09  1.350100e+08  4.504783e+09
# 2021-10-02  4.066595e+09  1.399944e+08  4.580609e+09
# 2021-10-03  4.075295e+09  1.500492e+08  4.687820e+09
# 2021-10-04  3.984976e+09  1.497508e+08  4.663548e+09
# 2021-10-05  4.470707e+09  1.553020e+08  4.762029e+09
# 2021-10-06  4.528760e+09  1.534946e+08  4.724335e+09
# 2021-10-07  4.483351e+09  1.577545e+08  4.696261e+09
# 2021-10-08  4.560892e+09  1.645999e+08  4.651345e+09
# 2021-10-09  5.069958e+09  1.935887e+08  4.486516e+09
# 2021-10-10  5.131014e+09  1.875108e+08  4.455768e+09

# %% [markdown]
# ## get_current_tvl

# %% [markdown]
# Retrive the current protocol tvl as a pandas DataFrame for an asset or list of assets

# %%
protocols = ["uniswap", "curve", "aave"]
current_tvl = dl.get_current_tvl(protocols)
current_tvl
# Out:
#                   tvl
# uniswap  1.040976e+10
# curve    2.115508e+10
# aave     1.629941e+10

# %% [markdown]
# ## get_protocols

# %% [markdown]
# Returns basic information on all DeFi Llama listed protocols, their current TVL and the changes to it in the last hour/day/week as a pandas DataFrame

# %%
protocols = dl.get_protocols()
protocols
# Out:
#                                                          curve  \
# id                                                           3
# name                                                     Curve
# address             0xD533a949740bb3306d119CC777fa900bA034cd52
# symbol                                                     CRV
# url                                           https://curve.fi
# description  Curve is a decentralized exchange liquidity po...
# chain                                              Multi-Chain
# logo                          https://icons.llama.fi/curve.png
# audits                                                       2
# audit_note                                                None
# gecko_id                                       curve-dao-token
# cmcId                                                     6538
# category                                                 Dexes
# chains       [Avalanche, Harmony, Ethereum, xDai, Polygon, ...
# module                                                curve.js
# twitter                                           CurveFinance
# audit_links                          [https://curve.fi/audits]
# oracles                                            [Chainlink]
# slug                                                     curve
# tvl                                         21155075853.727394
# chainTvls    {'Avalanche': 754799496.5488125, 'Harmony': 12...
# change_1h                                             0.263505
# change_1d                                             0.764904
# change_7d                                             1.245623
# fdv                                                13371823396
# mcap                                                1586783653
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                                   NaN
# pool2                                                      NaN
#
#                                                       makerdao  \
# id                                                         118
# name                                                  MakerDAO
# address             0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2
# symbol                                                     MKR
# url                                      https://makerdao.com/
# description  Builders of Dai, a digital currency that can b...
# chain                                                 Ethereum
# logo                       https://icons.llama.fi/makerdao.jpg
# audits                                                       2
# audit_note                                                None
# gecko_id                                                 maker
# cmcId                                                     1518
# category                                               Minting
# chains                                              [Ethereum]
# module                                          maker/index.js
# twitter                                               MakerDAO
# audit_links                   [https://security.makerdao.com/]
# oracles                                                [Maker]
# slug                                                  makerdao
# tvl                                         19028445059.159794
# chainTvls                     {'Ethereum': 19028445059.159794}
# change_1h                                             0.039202
# change_1d                                             0.768278
# change_7d                                             -3.54481
# fdv                                                 3060846696
# mcap                                                2743474279
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                                   NaN
# pool2                                                      NaN
#
#                                                           aave  \
# id                                                         111
# name                                                      AAVE
# address             0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9
# symbol                                                    AAVE
# url                                       https://aave.com\r\n
# description  Aave is an Open Source and Non-Custodial proto...
# chain                                              Multi-Chain
# logo                           https://icons.llama.fi/aave.png
# audits                                                       2
# audit_note                                                None
# gecko_id                                                  aave
# cmcId                                                     7278
# category                                               Lending
# chains                          [Ethereum, Polygon, Avalanche]
# module                                           aave/index.js
# twitter                                               AaveAave
# audit_links                        [https://aave.com/security]
# oracles                                            [Chainlink]
# slug                                                      aave
# tvl                                          16299412669.39081
# chainTvls    {'Ethereum': 11198413075.632769, 'Polygon': 19...
# change_1h                                            -0.812211
# change_1d                                             0.673447
# change_7d                                            -1.090278
# fdv                                                 4893114106
# mcap                                                4051515814
# staking                                      1390784633.969693
# forkedFrom                                                 NaN
# listedAt                                                   NaN
# pool2                                                      NaN
#
#                                                 convex-finance  \
# id                                                         319
# name                                            Convex Finance
# address             0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2b
# symbol                                                     CVX
# url                             https://www.convexfinance.com/
# description  Convex simplifies your Curve-boosting experien...
# chain                                                 Ethereum
# logo                 https://icons.llama.fi/convex-finance.jpg
# audits                                                       2
# audit_note                                                None
# gecko_id                                        convex-finance
# cmcId                                                     9903
# category                                                 Yield
# chains                                              [Ethereum]
# module                                         convex/index.js
# twitter                                          ConvexFinance
# audit_links  [https://github.com/convex-eth/platform/blob/m...
# oracles                                                    NaN
# slug                                            convex-finance
# tvl                                         15885584743.246418
# chainTvls                     {'Ethereum': 15885584743.246418}
# change_1h                                            -0.246987
# change_1d                                             0.795936
# change_7d                                             3.910702
# fdv                                                 2922407301
# mcap                                                1070996751
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                                   NaN
# pool2                                                      NaN
#
#                                                           wbtc  \
# id                                                           2
# name                                                      WBTC
# address             0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# symbol                                                    WBTC
# url                                      https://wbtc.network/
# description  Wrapped Bitcoin (WBTC) is the first ERC20 toke...
# chain                                                 Ethereum
# logo                           https://icons.llama.fi/wbtc.png
# audits                                                       2
# audit_note                                                None
# gecko_id                                       wrapped-bitcoin
# cmcId                                                     3717
# category                                                Assets
# chains                                              [Ethereum]
# module                                                 wbtc.js
# twitter                                             WrappedBTC
# audit_links             [https://wbtc.network/dashboard/audit]
# oracles                                            [Chainlink]
# slug                                                      wbtc
# tvl                                             15403712387.98
# chainTvls                         {'Ethereum': 15403712387.98}
# change_1h                                             0.703213
# change_1d                                             0.322254
# change_7d                                            -0.720664
# fdv                                                15421873362
# mcap                                               15421873362
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                                   NaN
# pool2                                                      NaN
#
#                                                      instadapp  \
# id                                                         120
# name                                                 Instadapp
# address             0x6f40d4a6237c257fff2db00fa0510deeecd303eb
# symbol                                                    INST
# url                                      https://instadapp.io/
# description  Aims to drive interoperability between protoco...
# chain                                                 Ethereum
# logo                      https://icons.llama.fi/instadapp.jpg
# audits                                                    None
# audit_note                                                None
# gecko_id                                             instadapp
# cmcId                                                    10508
# category                                              Services
# chains                                              [Ethereum]
# module                                            instadapp.js
# twitter                                              Instadapp
# audit_links  [https://github.com/Instadapp/dsa-contracts/bl...
# oracles                                                    NaN
# slug                                                 instadapp
# tvl                                                12809317079
# chainTvls                            {'Ethereum': 12809317079}
# change_1h                                                    0
# change_1d                                              1.52394
# change_7d                                              2.28879
# fdv                                                        NaN
# mcap                                                  80754551
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                                   NaN
# pool2                                                      NaN
#
#                                                       compound  \
# id                                                         114
# name                                                  Compound
# address             0xc00e94cb662c3520282e6f5717214004a7f26888
# symbol                                                    COMP
# url                                   https://compound.finance
# description  Compound is an algorithmic, autonomous interes...
# chain                                                 Ethereum
# logo                       https://icons.llama.fi/compound.png
# audits                                                       2
# audit_note                                                None
# gecko_id                             compound-governance-token
# cmcId                                                     5692
# category                                               Lending
# chains                                              [Ethereum]
# module                               compound-onchain/index.js
# twitter                                        compoundfinance
# audit_links           [https://compound.finance/docs/security]
# oracles                                            [Chainlink]
# slug                                                  compound
# tvl                                         12566277407.200264
# chainTvls                     {'Ethereum': 12566277407.200264}
# change_1h                                             -0.19961
# change_1d                                             0.831344
# change_7d                                            -1.375282
# fdv                                                 3414920877
# mcap                                                2100503637
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                                   NaN
# pool2                                                      NaN
#
#                                                        uniswap  \
# id                                                           1
# name                                                   Uniswap
# address             0x1f9840a85d5af5bf1d1762f925bdaddc4201f984
# symbol                                                     UNI
# url                                  https://info.uniswap.org/
# description  A fully decentralized protocol for automated l...
# chain                                                 Ethereum
# logo                        https://icons.llama.fi/uniswap.png
# audits                                                       2
# audit_note                                                None
# gecko_id                                               uniswap
# cmcId                                                     7083
# category                                                 Dexes
# chains                          [Optimism, Ethereum, Arbitrum]
# module                                        uniswap/index.js
# twitter                                                Uniswap
# audit_links  [https://github.com/Uniswap/uniswap-v3-core/tr...
# oracles                                              [Uniswap]
# slug                                                   uniswap
# tvl                                         10409755599.486263
# chainTvls    {'Optimism': 40914299.193099, 'Ethereum': 1030...
# change_1h                                            -0.219655
# change_1d                                            -0.608482
# change_7d                                                 None
# fdv                                                24331678216
# mcap                                               11018985771
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                                   NaN
# pool2                                                      NaN
#
#                                                           lido  \
# id                                                         182
# name                                                      Lido
# address             0x5a98fcbea516cf06857215779fd812ca3bef1b32
# symbol                                                     LDO
# url                                           https://lido.fi/
# description  Liquidity for staked assets. Daily rewards, no...
# chain                                              Multi-Chain
# logo                           https://icons.llama.fi/lido.png
# audits                                                       2
# audit_note                                                None
# gecko_id                                              lido-dao
# cmcId                                                     8000
# category                                               Staking
# chains                               [Ethereum, Solana, Terra]
# module                                           lido/index.js
# twitter                                            LidoFinance
# audit_links            [https://github.com/lidofinance/audits]
# oracles                                                    NaN
# slug                                                      lido
# tvl                                         10381539687.989788
# chainTvls    {'Ethereum': 6784135193.697066, 'Solana': 2467...
# change_1h                                             0.122149
# change_1d                                             0.416144
# change_7d                                             -4.73353
# fdv                                                 4296098688
# mcap                                                 261322363
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                                   NaN
# pool2                                                      NaN
#
#                                polygon-bridge-&-staking  ...  \
# id                                                  240  ...
# name                           Polygon Bridge & Staking  ...
# address      0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0  ...
# symbol                                            MATIC  ...
# url                         https://polygon.technology/  ...
# description                      Ethereum sidechain\r\n  ...
# chain                                           Polygon  ...
# logo                 https://icons.llama.fi/polygon.jpg  ...
# audits                                                0  ...
# audit_note                                         None  ...
# gecko_id                                  matic-network  ...
# cmcId                                              3890  ...
# category                                          Chain  ...
# chains                                        [Polygon]  ...
# module                                 polygon/index.js  ...
# twitter                                       0xPolygon  ...
# audit_links                                         NaN  ...
# oracles                                             NaN  ...
# slug                           polygon-bridge-&-staking  ...
# tvl                                  10369939633.671995  ...
# chainTvls               {'Polygon': 10369939633.671995}  ...
# change_1h                                      0.133525  ...
# change_1d                                      0.702044  ...
# change_7d                                     -5.000815  ...
# fdv                                         17245775779  ...
# mcap                                        11852832273  ...
# staking                                             NaN  ...
# forkedFrom                                          NaN  ...
# listedAt                                            NaN  ...
# pool2                                               NaN  ...
#
#                                                          fegex  \
# id                                                         672
# name                                                     Fegex
# address             0x389999216860ab8e0175387a0c90e5c52522c945
# symbol                                                     FEG
# url                                       https://fegtoken.com
# description                            The All-in-One exchange
# chain                                              Multi-Chain
# logo                          https://icons.llama.fi/fegex.png
# audits                                                       2
# audit_note                                                None
# gecko_id                                             feg-token
# cmcId                                                     1437
# category                                               Staking
# chains                                              [Ethereum]
# module                                          fegex/index.js
# twitter                                               FEGtoken
# audit_links              [https://solidity.finance/audits/FEG]
# oracles                                                    NaN
# slug                                                     fegex
# tvl                                                          0
# chainTvls    {'Staking_bsc': 70245513.76838319, 'Staking_et...
# change_1h                                                 None
# change_1d                                                 None
# change_7d                                                 None
# fdv                                                        NaN
# mcap                                                 271759835
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                            1634319488
# pool2                                                      NaN
#
#                                                      oraichain  \
# id                                                         681
# name                                                 OraiChain
# address             0x4c11249814f11b9346808179cf06e71ac328c1b5
# symbol                                                    ORAI
# url                                            https://orai.io
# description  Oraichain is a data oracle platform that aggre...
# chain                                              Multi-Chain
# logo                      https://icons.llama.fi/oraichain.jpg
# audits                                                       2
# audit_note                                                None
# gecko_id                                       oraichain-token
# cmcId                                                     7533
# category                                                 Yield
# chains                                              [Ethereum]
# module                                            oraichain.js
# twitter                                              oraichain
# audit_links              [https://github.com/oraichain/audits]
# oracles                                                    NaN
# slug                                                 oraichain
# tvl                                                          0
# chainTvls    {'Binance-staking': 2528149.7054435015, 'Ether...
# change_1h                                                 None
# change_1d                                                 None
# change_7d                                                 None
# fdv                                                  365992830
# mcap                                                  41067910
# staking                                         5742539.621396
# forkedFrom                                                 NaN
# listedAt                                            1634551713
# pool2                                                      NaN
#
#                                                       bacondao  \
# id                                                         682
# name                                                  BaconDAO
# address         bsc:0x0615dbba33fe61a31c7ed131bda6655ed76748b1
# symbol                                                   BACON
# url                                  https://app.bacondao.com/
# description  BaconDAO (BACON) is a Decentralized Autonomous...
# chain                                              Multi-Chain
# logo                       https://icons.llama.fi/bacondao.png
# audits                                                       2
# audit_note                                                None
# gecko_id                                              bacondao
# cmcId                                                    10501
# category                                                 Yield
# chains                                     [Binance, Ethereum]
# module                                       bacondao/index.js
# twitter                                              BaconDAO_
# audit_links  [https://drive.google.com/file/d/1AVc_YuSKoaoj...
# oracles                                                    NaN
# slug                                                  bacondao
# tvl                                                          0
# chainTvls    {'pool2': 225306.17278419333, 'Binance-pool2':...
# change_1h                                                 None
# change_1d                                                 None
# change_7d                                                 None
# fdv                                                   11085135
# mcap                                                         0
# staking                                          125288.112294
# forkedFrom                                                 NaN
# listedAt                                            1634577126
# pool2                                            225306.172784
#
#                                                    yel-finance  \
# id                                                         686
# name                                               YEL Finance
# address             0x7815bda662050d84718b988735218cffd32f75ea
# symbol                                                     YEL
# url                                        https://yel.finance
# description  YEL aggregates multiple projects across severa...
# chain                                              Multi-Chain
# logo                    https://icons.llama.fi/yel-finance.png
# audits                                                       2
# audit_note                                                None
# gecko_id                                           yel-finance
# cmcId                                                    11301
# category                                                 Yield
# chains                                              [Ethereum]
# module                                            yel/index.js
# twitter                                            yel_finance
# audit_links  [https://yield-enhancement-labs.gitbook.io/yie...
# oracles                                                    NaN
# slug                                               yel-finance
# tvl                                                          0
# chainTvls    {'pool2': 7367527.737231406, 'Fantom-staking':...
# change_1h                                                 None
# change_1d                                                 None
# change_7d                                                 None
# fdv                                                   49640138
# mcap                                                  31047413
# staking                                        13147732.720452
# forkedFrom                                                 NaN
# listedAt                                            1634674060
# pool2                                           7367527.737231
#
#                                                      smartcoin  \
# id                                                         715
# name                                                 SmartCoin
# address        avax:0xCC2f1d827b18321254223dF4e84dE399D9Ff116c
# symbol                                                    SMRT
# url                                     https://smartcoin.farm
# description  SmartCoin is a yield farming protocol on Avala...
# chain                                                Avalanche
# logo                           https://icons.llama.fi/smrt.png
# audits                                                       2
# audit_note                                                None
# gecko_id                                           smartcoin-2
# cmcId                                                    12917
# category                                                 Yield
# chains                                             [Avalanche]
# module                                      smartcoin/index.js
# twitter                                            0xSmartCoin
# audit_links  [https://paladinsec.co/pld/assets/20211018_Pal...
# oracles                                                    NaN
# slug                                                 smartcoin
# tvl                                                          0
# chainTvls    {'Avalanche': 0, 'pool2': 86972.06811295587, '...
# change_1h                                                 None
# change_1d                                                 None
# change_7d                                                 None
# fdv                                                   14264539
# mcap                                                         0
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                            1635279168
# pool2                                             86972.068113
#
#                                              billion-happiness  \
# id                                                         716
# name                                         Billion Happiness
# address         bsc:0x6fd7c98458a943f469E1Cf4eA85B173f5Cd342F4
# symbol                                                     BHC
# url                          https://billionhappiness.finance/
# description  Billion Happiness is a blockchain community-ba...
# chain                                                  Binance
# logo              https://icons.llama.fi/billion-happiness.png
# audits                                                       2
# audit_note                                                None
# gecko_id                                      billionhappiness
# cmcId                                                     7182
# category                                                 Yield
# chains                                               [Binance]
# module                              billion-happiness/index.js
# twitter                                          BHC_Happiness
# audit_links  [https://www.certik.org/projects/billionhappin...
# oracles                                                    NaN
# slug                                         billion-happiness
# tvl                                                          0
# chainTvls    {'Binance': 0, 'Binance-staking': 4744401.0905...
# change_1h                                                 None
# change_1d                                                 None
# change_7d                                                 None
# fdv                                                        NaN
# mcap                                                  10278945
# staking                                          4744401.09059
# forkedFrom                                                 NaN
# listedAt                                            1635296377
# pool2                                            219075.413353
#
#                                                       decubate  \
# id                                                         717
# name                                                  Decubate
# address         bsc:0xEAc9873291dDAcA754EA5642114151f3035c67A2
# symbol                                                     DCB
# url                             https://platform.decubate.com/
# description  Decubate is a community-powered investment pla...
# chain                                                  Binance
# logo                       https://icons.llama.fi/decubate.png
# audits                                                       0
# audit_note                                                None
# gecko_id                                              decubate
# cmcId                                                    10563
# category                                             Launchpad
# chains                                               [Binance]
# module                                       decubate/index.js
# twitter                                               decubate
# audit_links                                                NaN
# oracles                                                    NaN
# slug                                                  decubate
# tvl                                                          0
# chainTvls    {'Binance': 0, 'Binance-staking': 2561925.3018...
# change_1h                                                 None
# change_1d                                                 None
# change_7d                                                 None
# fdv                                                   63523076
# mcap                                                   4060219
# staking                                         2561925.301835
# forkedFrom                                                 NaN
# listedAt                                            1635383289
# pool2                                                      NaN
#
#                                                         nasdex  \
# id                                                         720
# name                                                    Nasdex
# address      polygon:0xE8d17b127BA8b9899a160D9a07b69bCa8E08...
# symbol                                                    NSDX
# url                                     https://www.nasdex.xyz
# description  NASDEX is a decentralised app on polygon, that...
# chain                                                  Polygon
# logo                         https://icons.llama.fi/nasdex.png
# audits                                                       0
# audit_note                                                None
# gecko_id                                          nasdex-token
# cmcId                                                    12312
# category                                                 Dexes
# chains                                               [Polygon]
# module                                         nasdex/index.js
# twitter                                             nasdex_xyz
# audit_links                                                NaN
# oracles                                                    NaN
# slug                                                    nasdex
# tvl                                                          0
# chainTvls    {'pool2': 184061.26465574495, 'staking': 11098...
# change_1h                                                 None
# change_1d                                                 None
# change_7d                                                 None
# fdv                                                        NaN
# mcap                                                         0
# staking                                          1109814.56441
# forkedFrom                                                 NaN
# listedAt                                            1635463716
# pool2                                            184061.264656
#
#                                                      atmossoft  \
# id                                                         783
# name                                                 AtmosSoft
# address         bsc:0xC53C65C4A925039cC149fA99fD011490D40270a3
# symbol                                                 ATMSSFT
# url                              https://www.atmossoftdefi.app
# description  Atmosphere Software(AtmosSoft) is a next gener...
# chain                                              Multi-Chain
# logo                      https://icons.llama.fi/atmossoft.jpg
# audits                                                       0
# audit_note                                                None
# gecko_id                                                  None
# cmcId                                                     None
# category                                                Gaming
# chains                                                [Fantom]
# module                                            atmossoft.js
# twitter                                              AtmosSoft
# audit_links                                                NaN
# oracles                                                    NaN
# slug                                                 atmossoft
# tvl                                                          0
# chainTvls    {'pool2': 20291.51047458201, 'Fantom-pool2': 1...
# change_1h                                                 None
# change_1d                                                 None
# change_7d                                                 None
# fdv                                                        NaN
# mcap                                                       NaN
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                            1636043958
# pool2                                             20291.510475
#
#                                                         zigzag
# id                                                         800
# name                                                    ZigZag
# address                                                   None
# symbol                                                       -
# url                              https://trade.zigzag.exchange
# description  A Layer 2 decentralized exchange (DEX) on zkSync
# chain                                                   zkSync
# logo                         https://icons.llama.fi/zigzag.jpg
# audits                                                       0
# audit_note                                                None
# gecko_id                                                  None
# cmcId                                                     None
# category                                                 Dexes
# chains                                                [zkSync]
# module                                         zigzag/index.js
# twitter                                         ZigZagExchange
# audit_links                                                NaN
# oracles                                                    NaN
# slug                                                    zigzag
# tvl                                                          0
# chainTvls    {'Zksync': 0, 'offers': 159446.73925681648, 'Z...
# change_1h                                                 None
# change_1d                                                 None
# change_7d                                                 None
# fdv                                                        NaN
# mcap                                                       NaN
# staking                                                    NaN
# forkedFrom                                                 NaN
# listedAt                                            1636305888
# pool2                                                      NaN
#
# [30 rows x 697 columns]
