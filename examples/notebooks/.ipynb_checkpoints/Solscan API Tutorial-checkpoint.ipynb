# %% [markdown]
# # Solscan Llama Python API Tutorial

# %% [markdown]
# This tutorial aims to be a quick guide to get you started using the Solscan API integrated into messari's python library.

# %%
from messari.solscan import Solscan
ss = Solscan()

# %% [markdown]
# ## get_last_block

# %% [markdown]
# returns info for last num_blocks (default is 1, limit is 20)

# %%
last_block = ss.get_last_block(num_blocks=5)
last_block
# Out:
#    currentSlot                                             result
# 0    109458391  {'blockHeight': 98596903, 'blockTime': 1638298...
# 1    109458390  {'blockHeight': 98596902, 'blockTime': 1638298...
# 2    109458389  {'blockHeight': 98596901, 'blockTime': 1638298...
# 3    109458388  {'blockHeight': 98596900, 'blockTime': 1638298...
# 4    109458387  {'blockHeight': 98596899, 'blockTime': 1638298...

# %% [markdown]
# ## get_block_transactions

# %% [markdown]
# get last num_transactions (default is 10) transactions of given block numbers

# %%
blocks = ['109452586', '109452587']
block_transactions = ss.get_block_transactions(blocks)
block_transactions.head()
# Out:
#                                            109452586  \
#                                                 meta
# 0  {'err': None, 'fee': 5000, 'innerInstructions'...
# 1  {'err': None, 'fee': 5000, 'innerInstructions'...
# 2  {'err': None, 'fee': 5000, 'innerInstructions'...
# 3  {'err': None, 'fee': 5000, 'innerInstructions'...
# 4  {'err': None, 'fee': 5000, 'innerInstructions'...
#
#                                                       \
#                                          transaction
# 0  {'message': {'accountKeys': [{'pubkey': '92W5J...
# 1  {'message': {'accountKeys': [{'pubkey': '4XspX...
# 2  {'message': {'accountKeys': [{'pubkey': '4dV7p...
# 3  {'message': {'accountKeys': [{'pubkey': 'Cn2GF...
# 4  {'message': {'accountKeys': [{'pubkey': '8gcMm...
#
#                                            109452587  \
#                                                 meta
# 0  {'err': None, 'fee': 5000, 'innerInstructions'...
# 1  {'err': {'InstructionError': [0, 'InvalidArgum...
# 2  {'err': {'InstructionError': [0, 'InvalidArgum...
# 3  {'err': {'InstructionError': [0, 'InvalidArgum...
# 4  {'err': {'InstructionError': [0, 'InvalidArgum...
#
#
#                                          transaction
# 0  {'message': {'accountKeys': [{'pubkey': 'Ammvo...
# 1  {'message': {'accountKeys': [{'pubkey': 'Y2akr...
# 2  {'message': {'accountKeys': [{'pubkey': 'H8JEG...
# 3  {'message': {'accountKeys': [{'pubkey': 'HekM1...
# 4  {'message': {'accountKeys': [{'pubkey': 'Y2akr...

# %% [markdown]
# ## get_block

# %%
blocks = ['109452586', '109452587']
blocks_info = ss.get_block(blocks)
blocks_info
# Out:
#                     109452586                                                \
#                   currentSlot                                        result
# blockHeight         109452586                                      98591476
# blockTime           109452586                                    1638295085
# blockhash           109452586  GCTLNg2XZDzKgEmwiE8mRDTrjJEw9DC2nbo6Y73miHRL
# feeRewards          109452586                                       2815000
# parentSlot          109452586                                     109452585
# previousBlockhash   109452586  2iosCGrQ6CthviS8dDdJzqhULH1AvBTyDG3xspqnvfMD
# transactionCount    109452586                                          1112
# validator           109452586  3B2mGaZoFwzAnWCoZ4EAKdps4FbYbDKQ48jo8u1XWynU
#
#                     109452587
#                   currentSlot                                        result
# blockHeight         109452587                                      98591477
# blockTime           109452587                                    1638295085
# blockhash           109452587   sMUtedNEJGKZWTWoPUMaNfzKcYpm884wRJN6LHTPYSL
# feeRewards          109452587                                       4945000
# parentSlot          109452587                                     109452586
# previousBlockhash   109452587  GCTLNg2XZDzKgEmwiE8mRDTrjJEw9DC2nbo6Y73miHRL
# transactionCount    109452587                                          1961
# validator           109452587  3B2mGaZoFwzAnWCoZ4EAKdps4FbYbDKQ48jo8u1XWynU

# %% [markdown]
# ## get_last_transaction

# %% [markdown]
# return last num_transactions (default 10, limit 20) transactions

# %%
last_transactions = ss.get_last_transaction(num_transactions=5)
last_transactions
# Out:
#                                                 meta  \
# 0  {'err': {'InstructionError': [0, 'InvalidArgum...
# 1  {'err': None, 'fee': 5000, 'innerInstructions'...
# 2  {'err': {'InstructionError': [0, 'InvalidArgum...
# 3  {'err': {'InstructionError': [0, 'InvalidArgum...
# 4  {'err': {'InstructionError': [0, 'InvalidArgum...
#
#                                          transaction
# 0  {'message': {'accountKeys': [{'pubkey': 'HekM1...
# 1  {'message': {'accountKeys': [{'pubkey': 'HekM1...
# 2  {'message': {'accountKeys': [{'pubkey': 'HekM1...
# 3  {'message': {'accountKeys': [{'pubkey': 'HfeFy...
# 4  {'message': {'accountKeys': [{'pubkey': 'GvJVH...

# %% [markdown]
# ## get_transaction

# %%
transactions=['T4ipYTjKUqHQpfuA8ZM5E4iJag9kX9nGhjbY974oq2ucyYRL6eWhqTjtmk3cqfqTSu8Qdce33vzKQd7bWEX3H21']
transactions_info = ss.get_transaction(transactions)
transactions_info
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/0z/kwj7z5bd6rz4n3hl73_qgnn40000gn/T/ipykernel_25444/4241734135.py in <module>
#       1 txns=['T4ipYTjKUqHQpfuA8ZM5E4iJag9kX9nGhjbY974oq2ucyYRL6eWhqTjtmk3cqfqTSu8Qdce33vzKQd7bWEX3H21']
# ----> 2 transaction = ss.get_transaction(txns)
#       3 transaction
#
# /usr/local/lib/python3.9/site-packages/messari-0.0.1-py3.9.egg/messari/solscan/solscan.py in get_transaction(self, signatures_in)
#     144             response = self.get_response(endpoint_url,
#     145                                         headers=HEADERS)
# --> 146             df = pd.DataFrame(response)
#     147             print(response)
#     148             df_list.append(df)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ## get_account_tokens

# %%
accounts = ['Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ', '7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS']
account_tokens = ss.get_account_tokens(accounts)
account_tokens.head()
# Out:
#    Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ  \
#                                    tokenAddress
# 0   KNVfdSJyq1pRQk9AKKv1g5uyGuk6wpm4WG16Bjuwdma
# 1   PoRTjZMPXb9T7dyU7tpLEZRQj7e6ssfAE62j2oQuc6y
# 2  7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs
# 3  ATLASXmbPQxBUYbxPsV97usA3fPQYEqzQBUHgiFCUsXx
# 4  FTT9rBBrYwcHam4qLvkzzzhrsihYMbZ3k6wJbdoahxAt
#
#                                                       \
#                                          tokenAmount
# 0  {'amount': '0', 'decimals': 9, 'uiAmount': 0, ...
# 1  {'amount': '10518756', 'decimals': 6, 'uiAmoun...
# 2  {'amount': '0', 'decimals': 8, 'uiAmount': 0, ...
# 3  {'amount': '0', 'decimals': 8, 'uiAmount': 0, ...
# 4  {'amount': '0', 'decimals': 9, 'uiAmount': 0, ...
#
#                                                  \
#                                    tokenAccount
# 0  8w3DXCuLfmncbscY2ZPHSFm7RQ6qpFTv7ZQTeSkrHScU
# 1  4E4wTBurw6jguirauunPuGciqxtUTUNecgpseUUt1L8W
# 2  2uMiF9vPEogw9GiZa9UvPFxffoJpSUF6zKmWwKKjm2D3
# 3  7UQsVoVHrrkay8uGVm9rXbtAJfdgjjE1NSdVQs1KC1BB
# 4  CWhrA3kVqd3uqC1YPF1bh1tSfUNH2VUNBsUuicttkt8D
#
#                                                     \
#                                          tokenName
# 0      Saber Wrapped Ether (Wormhole) (9 decimals)
# 1                               Port Finance Token
# 2                         Wrapped Ether (Wormhole)
# 3                                       Star Atlas
# 4  Saber Wrapped Wrapped FTT (Sollet) (9 decimals)
#
#                                                                          \
#                                            tokenIcon rentEpoch lamports
# 0  https://raw.githubusercontent.com/solana-labs/...       252  2039280
# 1  https://raw.githubusercontent.com/solana-labs/...       253  2039280
# 2  https://raw.githubusercontent.com/solana-labs/...       253  2039280
# 3  https://raw.githubusercontent.com/solana-labs/...       253  2039280
# 4  https://raw.githubusercontent.com/solana-labs/...       252  2039280
#
#
#   tokenSymbol    priceUsdt
# 0    swhETH-9  4603.650000
# 1        PORT     3.470000
# 2      weWETH  4630.850000
# 3       ATLAS     0.192094
# 4      sFTT-9    50.900000

# %% [markdown]
# ## get_account_transactions

# %%
accounts = ['Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ', '7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS']
account_transactions = ss.get_account_transactions(accounts)
account_transactions
# Out:
#   Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ             \
#                                      blockTime       slot
# 0                                   1638215578  109311089
# 1                                   1637794056  108544981
# 2                                   1637794009  108544891
# 3                                   1637793936  108544749
# 4                                   1637793766  108544423
# 5                                   1637774901  108509896
# 6                                   1637774890  108509877
# 7                                   1637774874  108509849
# 8                                   1637771911  108504697
# 9                                   1637771822  108504549
#
#                                                                               \
#                                               txHash    fee   status lamport
# 0  5otAVzzVx1WhukCS9roWjM9jiTRF2rVG6J9zgB7Tg5G2RJ...  10000  Success       0
# 1  5DiefMeGxTkYqJ6bBkZMR2rR2PEYkZLcKqNxNputNxf9CE...   5000  Success       0
# 2  54HqcfsRxUiuQpTz93WzGUeyWfzKoNQ5Ury515gnNXRmdy...   5000  Success       0
# 3  5UCiUKeqbkYoAhbbYKehE4So3dt44VG8L3eq4dP8mYnYsS...   5000  Success       0
# 4  2Asw4nybj7EkUj3sRMEJPv1T5maS2TKpptyfNeEiNqFXrX...   5000  Success       0
# 5  2is3HZNdKWWQf9D4d18bjXEHdbb2mHCpMDRonZabMPzLz8...   5000  Success       0
# 6  5hJhu4RYQLZF3zBwTUzu6vbvt6kX71uoFTTdx6NurkESEe...   5000  Success       0
# 7  268iY4gCC2956AcmhFMVtriaxL7Qv7QBfF7GmSEkMaJXyB...   5000  Success       0
# 8  4afVqMDpf7ojUCh2yUS5JJUthktzjwcb5GLa6N5hL5D68o...  10000  Success       0
# 9  5VUx6GKjahiGuzMnxhMgtsu1T8trZVZ55uMTeoXqpH5Cqg...   5000  Success       0
#
#                                                       \
#                                               signer
# 0  [Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ,...
# 1     [Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ]
# 2     [Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ]
# 3     [Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ]
# 4     [Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ]
# 5     [Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ]
# 6     [Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ]
# 7     [Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ]
# 8  [Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ,...
# 9     [Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ]
#
#                                                       \
#                                    parsedInstruction
# 0  [{'programId': 'TokenkegQfeZyiNwAJbNbGKPFXCWuB...
# 1  [{'programId': 'So1endDq2YkqhipRh3WViPa8hdiSpx...
# 2  [{'programId': 'Crt7UoUR6QgrFrN7j8rmSQpUTNWNSi...
# 3  [{'programId': '9xQeWvG816bUx9EPjHmaT23yvVM2ZW...
# 4  [{'programId': '9xQeWvG816bUx9EPjHmaT23yvVM2ZW...
# 5  [{'programId': '9xQeWvG816bUx9EPjHmaT23yvVM2ZW...
# 6  [{'programId': '9xQeWvG816bUx9EPjHmaT23yvVM2ZW...
# 7  [{'programId': '9xQeWvG816bUx9EPjHmaT23yvVM2ZW...
# 8  [{'programId': 'ATokenGPvbdGVxr1b2hvZbsiqW5xWH...
# 9  [{'programId': 'Crt7UoUR6QgrFrN7j8rmSQpUTNWNSi...
#
#   7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS             \
#                                      blockTime       slot
# 0                                   1638312773  109483241
# 1                                   1638312708  109483128
# 2                                   1638312643  109482997
# 3                                   1638283135  109433415
# 4                                   1637608195  108198663
# 5                                   1637608179  108198633
# 6                                   1637606668  108195949
# 7                                   1637606645  108195904
# 8                                   1637598123  108179911
# 9                                   1637188873  107396440
#
#                                                                               \
#                                               txHash    fee   status lamport
# 0  nSiraE44sceN7AFqPRT9HuYAu8DPwVPaKCuPATqB9GFFmV...   5000  Success       0
# 1  3AS5Li82mhbQkvY4fCKDZHWrDVLJCNzV96ZsF7y7PyiJZd...  10000  Success       0
# 2  2vB6XziN7P8Wjhwm3nnKCka2xE66785Vqtb1BkgesKYmab...   5000  Success       0
# 3  4RWpSxiWAWijkQkD9GoqRxchcaZB8HqbGaRffMRXbZbPht...   5000  Success       0
# 4  664X8stHk1cVrP7QdZGaX1f8LN67J7aDCNWGQhbWpeXTxF...   5000  Success       0
# 5  2e6HLb7bmtfHhoerBc1NRg5n8cNvkAqZ29zCKTSX2XDsoi...   5000  Success       0
# 6  2zBH56m9MzWUQewmjpUU2phS6ZAzjtBWjqdqZn7LEvqSfZ...   5000  Success       0
# 7  5KBjN4LeQHwwgSJ1LvQMYW7aDo6x8KnS7P53yA75d95P8N...  10000  Success       0
# 8  5HWfFYfPp77TjWepHoZ3NVsmUF9xGispoBPu6BNmGAxuza...   5000  Success       0
# 9  4S2tJqfFCRdzWh35NoyRdehCRJwkETTo3hq1gWpJNUev8S...   5000  Success       0
#
#                                                       \
#                                               signer
# 0     [6j9E8PwXX2f6B2wv5vL9AcYJQDP2CrBcSUP69FdJSEZC]
# 1  [7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS,...
# 2     [7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS]
# 3     [4ZwSyo2oWiqb1RzhCnrqvAKyxmuJwW7dscsg6qnEXVfJ]
# 4     [7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS]
# 5     [7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS]
# 6     [7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS]
# 7  [7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS,...
# 8     [4ZwSyo2oWiqb1RzhCnrqvAKyxmuJwW7dscsg6qnEXVfJ]
# 9     [7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS]
#
#
#                                    parsedInstruction
# 0  [{'programId': 'ATokenGPvbdGVxr1b2hvZbsiqW5xWH...
# 1  [{'programId': '111111111111111111111111111111...
# 2  [{'programId': 'ATokenGPvbdGVxr1b2hvZbsiqW5xWH...
# 3  [{'programId': '111111111111111111111111111111...
# 4  [{'programId': 'ATokenGPvbdGVxr1b2hvZbsiqW5xWH...
# 5  [{'programId': 'ATokenGPvbdGVxr1b2hvZbsiqW5xWH...
# 6  [{'programId': 'ATokenGPvbdGVxr1b2hvZbsiqW5xWH...
# 7  [{'programId': '111111111111111111111111111111...
# 8  [{'programId': '111111111111111111111111111111...
# 9  [{'programId': '111111111111111111111111111111...

# %% [markdown]
# ## get_account_stake

# %%
accounts = ['Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ', '7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS']
account_stake = ss.get_account_stake(accounts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/0z/kwj7z5bd6rz4n3hl73_qgnn40000gn/T/ipykernel_25444/2176419042.py in <module>
# ----> 1 account_stake = ss.get_account_stake()
#
# TypeError: get_account_stake() missing 1 required positional argument: 'accounts_in'

# %% [markdown]
# ## get_account_spl_transactions

# %%
accounts = ['Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ', '7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS']
account_spl_transactions = ss.get_account_spl_transactions(accounts)

# %% [markdown]
# ## get_account_sol_transactions

# %%
accounts = ['Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ', '7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS']
account_sol_transactions = ss.get_account_sol_transactions(accounts)

# %% [markdown]
# ## get_account_export_transactions

# %%
accounts = ['Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ', '7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS']
account_export_transactions = ss.get_account_export_transactions(accounts)

# %% [markdown]
# ## get_account

# %%
accounts = ['Fhhq7AtgMsWge7oBMMWkqaF4boMLJ6Utcmc2X1oEsqJQ', '7MwQuB8vsCosYiqY4NCBDiECgsv5aFDYP3Zd5zBT6oaS']
account = ss.get_account(accounts)

# %% [markdown]
# ## get_token_holders

# %%
token_holders = ss.get_token_holders()

# %% [markdown]
# ## get_token_meta

# %%
tokens = ['Saber2gLauYim4Mvftnrasomsv6NvAuncvMEZwcLpD1', 'UXPhBoR3qG4UCiGNJfV7MqhHyFqKN68g45GoYvAeL2M']
token_meta = ss.get_token_meta(tokens)

# %% [markdown]
# ## get_token_list

# %%
token_list = ss.get_token_list()

# %% [markdown]
# ## get_market_info

# %%
market_info = ss.get_market_info()

# %% [markdown]
# ## get_chain_info

# %%
chain_info = ss.get_chain_info()
chain_info
